# %% [markdown]
# 01. Importing Libraries

# %%
# importing libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# 02. Importing Data

# %%
path = r'/Users/kevinclancy/Desktop/Master Folder'

# %%
# importing orders_products_combined
df_orders_products_combined = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %%
# checking orders_products_combined_shape
df_orders_products_combined.shape
# Out:
# (32640698, 13)

# %%
# checking order_products_combined_head
df_orders_products_combined.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_number  \
# 0             0           0   2539329        1             1
# 1             0           0   2539329        1             1
# 2             0           0   2539329        1             1
# 3             0           0   2539329        1             1
# 4             0           0   2539329        1             1
#
#    orders_day_of_week  order_hour_of_day  last_order  first_order  product_id  \
# 0                   2                  8         NaN         True       196.0
# 1                   2                  8         NaN         True     14084.0
# 2                   2                  8         NaN         True     12427.0
# 3                   2                  8         NaN         True     26088.0
# 4                   2                  8         NaN         True     26405.0
#
#    add_to_cart_order  reordered _merge
# 0                1.0        0.0   both
# 1                2.0        0.0   both
# ...

# %%
# importing products_checked
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products_checked.csv'), index_col = False)

# %%
# checking products_checked_shape
df_prods.shape
# Out:
# (49672, 6)

# %%
# checking products_checked_head
df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
# dropping unnamed columns in orders_products_combined
df_orders_products_combined = df_orders_products_combined.drop(columns = ['Unnamed: 0', 'Unnamed: 0.1'])

# %%
df_orders_products_combined.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    last_order  first_order  product_id  add_to_cart_order  reordered _merge
# 0         NaN         True       196.0                1.0        0.0   both
# 1         NaN         True     14084.0                2.0        0.0   both
# 2         NaN         True     12427.0                3.0        0.0   both
# 3         NaN         True     26088.0                4.0        0.0   both
# 4         NaN         True     26405.0                5.0        0.0   both

# %%
# dropping unnamed column in products_checked
df_prods = df_prods.drop(columns = ['Unnamed: 0'])

# %%
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %% [markdown]
# 03. Merging Data

# %%
# merging orders_products_combined with products_checked
df_orders_products_merged = df_orders_products_combined.merge(df_prods,on ='product_id')

# %%
df_orders_products_merged.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    last_order  first_order  product_id  add_to_cart_order  reordered _merge  \
# 0         NaN         True       196.0                1.0        0.0   both
# 1        15.0        False       196.0                1.0        1.0   both
# 2        21.0        False       196.0                1.0        1.0   both
# 3        29.0        False       196.0                1.0        1.0   both
# 4        28.0        False       196.0                1.0        1.0   both
#
#   product_name  aisle_id  department_id  prices
# ...

# %%
df_orders_products_merged['_merge'].value_counts()
# Out:
# _merge
# both          32404859
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %% [markdown]
# 04. Exporting

# %%
df_orders_products_merged.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))
